# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
import string

# %% [markdown]
# ### Models

# %%
from sdv.tabular import GaussianCopula # Importing 'GaussianCoupla' Model
from sdv.tabular import CTGAN # Importing 'CTGAN' Model
from sdv.tabular import CopulaGAN # Importing 'CopulaGAN' Model

# %% [markdown]
# ### Evaluation

# %%
from sdv.evaluation import evaluate # Importing 'evaluate' Class for Synthetic Dataset Evaluation

# %% [markdown]
# **xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx**

# %% [markdown]
# ## Removing Warning Messages

# %%
warnings.filterwarnings(action = 'ignore') # Removing Warning Messages

# %% [markdown]
# **xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx**

# %% [markdown]
# ## Importing Dataset

# %%
dataset = pd.read_spss('Data/bsa19_for_ukda.sav') # Importing Dataset

# %% [markdown]
# **xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx**

# %% [markdown]
# ## Dataset Context

# %%
dataset.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3224 entries, 0 to 3223
# Data columns (total 572 columns):
#  #    Column                Dtype
# ---   ------                -----
#  0    Sserial               category
#  1    spoint                float64
#  2    StratID               category
#  3    WtFactor              category
#  4    OldWt                 category
#  5    ABCVer                category
#  6    Country               category
#  7    GOR_ID                category
#  8    ruralEW               category
#  9    ruralSc               category
#  10   HousehldE             category
#  11   RSex                  category
#  12   RageE                 category
#  13   RAgeCat               category
#  14   RAgeCat2              category
#  15   RAgecat3              category
#  16   RAgecat4              category
#  17   RAgecat5              category
#  18   RSexAge               category
#  19   RSexAge2              category
#  20   MarStat               category
#  21   Married               category
#  22   LegMarStE             category
#  23   ChildHh               category
#  24   NCh415E               category
#  25   NCh318E               category
#  26   hhch04E               category
#  27   hhch511E              category
#  28   hhch1215E             category
#  29   hhch1617E             category
#  30   rch04E                category
#  31   rch511E               category
#  32   rch1215E              category
#  33   rch1617E              category
#  34   HhtypeE               category
#  35   Readpap               category
#  36   WhPaper               category
#  37   paptype               category
#  38   TVNews                category
#  39   WebNews               category
#  40   WNwSite1              category
#  41   WNwSite2              category
#  42   SMNews                category
#  43   Internet              category
#  44   IntPers               category
#  45   SupParty              category
#  46   ClosePty              category
#  47   PartyIDN              category
#  48   Partyid1              category
#  49   PartyId2              category
#  50   PartyID3              category
#  51   PtyAlleg              category
#  52   Idstrng               category
#  53   RemLea                category
#  54   RemLeaCl              category
#  55   RemLeaSt              category
#  56   Politics              category
#  57   SocTrust              category
#  58   SplitS                category
#  59   GovPrio1C             category
#  60   GovPrio2C             category
#  61   ECPolicy2             category
#  62   MiEcono               category
#  63   MiCultur              category
#  64   MiJobs                category
#  65   GovtWork              category
#  66   GovTrust              category
#  67   MPsTrust              category
#  68   LoseTch               category
#  69   VoteIntr              category
#  70   PtyNMat2              category
#  71   GovNoSay              category
#  72   VoteOnly              category
#  73   GovComp               category
#  74   Spend1                category
#  75   Spend2                category
#  76   Dole                  category
#  77   TaxSpend              category
#  78   SRInc                 category
#  79   MuchPov               category
#  80   PastPov               category
#  81   FuturPov              category
#  82   Poverty1              category
#  83   Poverty2              category
#  84   Poverty3              category
#  85   PovRedu1              category
#  86   PovRedu2              category
#  87   PovRedu3              category
#  88   PovRedu4              category
#  89   PovRedu5              category
#  90   PovRedu6              category
#  91   PovRedu7              category
#  92   PovRedu8              category
#  93   PovRedu9              category
#  94   PovRed11              category
#  95   MigWBen               category
#  96   MigWBenB              category
#  97   WkMent                category
#  98   WkPhys                category
#  99   HProbRsp              category
#  100  PhsRetn               category
#  101  PhsRecov              category
#  102  MntRetn               category
#  103  MntRecov              category
#  104  HCWork21              category
#  105  HCWork22              category
#  106  HCWork23              category
#  107  HCWork24              category
#  108  HCWork25              category
#  109  HCWork26              category
#  110  HCWork27              category
#  111  HCWork28              category
#  112  HCWork29              category
#  113  NatFrEst              category
#  114  FalseBn2              category
#  115  RepFrau3              category
#  116  RepWho1               category
#  117  RepWho2               category
#  118  RepWho3               category
#  119  RepWho4               category
#  120  RepWho5               category
#  121  RepWho6               category
#  122  RepWho7               category
#  123  RepWho8               category
#  124  RepWho9               category
#  125  RepWho10              category
#  126  WhyNRep1              category
#  127  WhyNRep2              category
#  128  WhyNRep3              category
#  129  WhyNRep4              category
#  130  WhyNRep5              category
#  131  WhyNRep6              category
#  132  WhyNRep7              category
#  133  WhyNRep8              category
#  134  WhyNRep9              category
#  135  AwrPB                 category
#  136  AdminPn2              category
#  137  LosofBen              category
#  138  AwrCRec               category
#  139  GovDoBF               category
#  140  NHSSat                category
#  141  WhySat1               category
#  142  WhySat2               category
#  143  WhySat3               category
#  144  WhySat4               category
#  145  WhySat5               category
#  146  WhySat6               category
#  147  WhySat7               category
#  148  WhySat8               category
#  149  WhySat9               category
#  150  WhySat10              category
#  151  WhyDis1               category
#  152  WhyDis2               category
#  153  WhyDis3               category
#  154  WhyDis4               category
#  155  WhyDis5               category
#  156  WhyDis6               category
#  157  WhyDis7               category
#  158  WhyDis8               category
#  159  WhyDis9               category
#  160  WhyDis10              category
#  161  GPSat                 category
#  162  DentSat               category
#  163  InpatSat              category
#  164  OutpaSat              category
#  165  AESat                 category
#  166  CareSat3              category
#  167  NHSFProb              category
#  168  NHS5yrs               category
#  169  Say5Yrs               category
#  170  NHSNx5Yr              category
#  171  NHSAcc                category
#  172  NHSCont1              category
#  173  NHSCont2              category
#  174  NHSCont3              category
#  175  NHSCont4              category
#  176  NHSCont5              category
#  177  NHSCont6              category
#  178  NHSCont7              category
#  179  StrctScl              category
#  180  SclPhon               category
#  181  BrkPhon               category
#  182  LrnPhon               category
#  183  SecScl                category
#  184  LrnOnlin              category
#  185  WishLrn1              category
#  186  WishLrn2              category
#  187  WishLrn3              category
#  188  WishLrn4              category
#  189  WishLrn5              category
#  190  WishLrn6              category
#  191  WishLrn7              category
#  192  WishLrn8              category
#  193  WishLrn9              category
#  194  WishLrn10             category
#  195  GetJbNow              category
#  196  HelpJob1              category
#  197  EUBrld                category
#  198  EUImpSov              category
#  199  EUExInf2              category
#  200  EUExEco2              category
#  201  Tranneed              category
#  202  Prejtran              category
#  203  TWomToil              category
#  204  TManToil              category
#  205  TWomRefu              category
#  206  TBirCert              category
#  207  PMS                   category
#  208  HomoSex               category
#  209  BeLike1               category
#  210  BeLike2               category
#  211  BeLike3               category
#  212  BeLike4               category
#  213  BeLike5               category
#  214  BeLike6               category
#  215  BeLike7               category
#  216  BeLike8               category
#  217  BeLike9               category
#  218  SeenAs1               category
#  219  SeenAs2               category
#  220  SeenAs3               category
#  221  SeenAs4               category
#  222  SeenAs5               category
#  223  SeenAs6               category
#  224  SeenAs7               category
#  225  SeenAs8               category
#  226  SeenAs9               category
#  227  SeenAs10              category
#  228  DMPSens               category
#  229  DMPPhys               category
#  230  DMPMent2              category
#  231  PrejNow               category
#  232  PrejFut               category
#  233  SRPrej                category
#  234  Racelaw               category
#  235  CCBELIEV              category
#  236  CanLegal              category
#  237  ECigNam1              category
#  238  ECigNam2              category
#  239  ECigNam3              category
#  240  ECigNam4              category
#  241  ECigNam5              category
#  242  ECigNam6              category
#  243  ECigNam7              category
#  244  ECigNam8              category
#  245  ECigNam98             category
#  246  VapHabit              category
#  247  Vapestat              category
#  248  CigHabit              category
#  249  Smokstat              category
#  250  VapHarm               category
#  251  VapLong               category
#  252  VapSafer              category
#  253  VapBoth               category
#  254  VapExp                category
#  255  VapPass               category
#  256  VapQuit               category
#  257  MediaVap              category
#  258  ReconActE             category
#  259  REconSum              category
#  260  RLastJob              category
#  261  RClass                category
#  262  RClassGp              category
#  263  RSuperv               category
#  264  REmpWork              category
#  265  REmpWrk2              category
#  266  SNumEmp               category
#  267  WkJbTim               category
#  268  ESrJbTim              category
#  269  SSrJbTim              category
#  270  WkJbHrsI              category
#  271  ExPrtFul              category
#  272  EJbHrCaI              category
#  273  SJbHrCaI              category
#  274  RPartFul              category
#  275  Remplyee              category
#  276  UnionSA               category
#  277  TUSAEver              category
#  278  TUSAEv                category
#  279  NPWork10              category
#  280  RES2010               category
#  281  RES2000               category
#  282  rjbtype               category
#  283  REconPos              category
#  284  ROcSect2E             category
#  285  RSIC07GpE             category
#  286  RNSEGGrp              category
#  287  RNSocCl               category
#  288  RnsegD                category
#  289  SeconActE             category
#  290  SLastJob              category
#  291  S2Employ              category
#  292  S2Superv              category
#  293  S2PartF2              category
#  294  S2ES2010              category
#  295  S2ES2000              category
#  296  seconsum              category
#  297  S2NSocCl              category
#  298  S2Class               category
#  299  S2ClassG              category
#  300  CareLeav              category
#  301  CareLpay              category
#  302  CarerHM1              category
#  303  CarerHM2              category
#  304  CarCJbR1              category
#  305  CarCJbR2              category
#  306  CarCJbR3              category
#  307  CarCJbR4              category
#  308  CarCJbR5              category
#  309  CarCJbR6              category
#  310  CarPJbR1              category
#  311  CarPJbR2              category
#  312  CarPJbR3              category
#  313  CarPJbR4              category
#  314  CarPJbR5              category
#  315  CarPJbR6              category
#  316  CarPJbR7              category
#  317  CarPJbR8              category
#  318  CarPJbR9              category
#  319  CarPJbR10             category
#  320  CarPJbR11             category
#  321  CarPJbR12             category
#  322  CarJbLf1              category
#  323  CarJbLf2              category
#  324  CarJbLf3              category
#  325  CarJbLf4              category
#  326  CarJbLf5              category
#  327  CarJbLf6              category
#  328  CarJbLf7              category
#  329  CarJbLf8              category
#  330  CarJbLf9              category
#  331  CarJbLf10             category
#  332  CarJbCu1              category
#  333  CarJbCu2              category
#  334  CarJbCu3              category
#  335  CarJbCu4              category
#  336  CarJbCu5              category
#  337  CarJbCu6              category
#  338  CarJbCu7              category
#  339  CarJbCu8              category
#  340  CarJbCu9              category
#  341  CarJbCu10             category
#  342  RetExp                category
#  343  RetExpb               category
#  344  DVRetAge              category
#  345  RetChng               category
#  346  Ear5W1                category
#  347  Ear5W2                category
#  348  Ear5W3                category
#  349  Ear5W4                category
#  350  Lat5Wh21              category
#  351  Lat5Wh22              category
#  352  Lat5Wh23              category
#  353  Lat5Wh24              category
#  354  Lat5Wh25              category
#  355  FutrWrk               category
#  356  WkOKeep1              category
#  357  WkOKeep2              category
#  358  WkOKeep3              category
#  359  WkOKeep4              category
#  360  WkOKeep5              category
#  361  WkOKeep6              category
#  362  WkOKeep7              category
#  363  WkOKeep8              category
#  364  WkOFl55               category
#  365  PenKnow2              category
#  366  PenExp2               category
#  367  RetirAg3              category
#  368  FxPT                  category
#  369  FXRed                 category
#  370  FxJbSh                category
#  371  FxFlex                category
#  372  FxComp                category
#  373  FxAnn                 category
#  374  FxTTwk                category
#  375  FxUL                  category
#  376  FXHome                category
#  377  FxOther               category
#  378  FxNone                category
#  379  WkPKnw                category
#  380  WKPSav                category
#  381  WkPSpn                category
#  382  WPSvUs                category
#  383  WPSvWw                category
#  384  WkPEFv                category
#  385  WkPFFv                category
#  386  WPSvEas               category
#  387  WPSvPra               category
#  388  PrPKnw                category
#  389  PrPSav                category
#  390  PrPSpn                category
#  391  PrPSvUs               category
#  392  PrPSvWW               category
#  393  PrPFFv                category
#  394  PrPSvEas              category
#  395  PrPSvPra              category
#  396  RPenSrc1              category
#  397  RPenSrc2              category
#  398  RPenSrc3              category
#  399  NatIdGB               category
#  400  Tenure2E              category
#  401  ResPres               category
#  402  ReligSum              category
#  403  RlFamSum              category
#  404  ChAttend              category
#  405  BestNatU2             category
#  406  raceori4              category
#  407  DisNew2               category
#  408  DisAct                category
#  409  DisActDV              category
#  410  Tea3                  category
#  411  HEdQual               category
#  412  HEdQual2              category
#  413  HEdQual3              category
#  414  EUIdent               category
#  415  EURefV2               category
#  416  EUVOTWHO              category
#  417  EURefb                category
#  418  EUParVot              category
#  419  EUParPty              category
#  420  AnyBN3                category
#  421  MainInc5              category
#  422  HHIncD                category
#  423  HHIncQ                category
#  424  REarnD                category
#  425  REarnQ                category
#  426  SelfComp              category
#  427  ahead1                category
#  428  ahead2                category
#  429  ahead3                category
#  430  ahead6                category
#  431  ahead7                category
#  432  ahead8                category
#  433  ahead14               category
#  434  ahead9                category
#  435  ahead10               category
#  436  ahead12               category
#  437  jobpay2               category
#  438  jobpay5               category
#  439  jobpy12b              category
#  440  jobpay10              category
#  441  jobpay11              category
#  442  shdpay2               category
#  443  shdpay5               category
#  444  shdpy12b              category
#  445  shdpay10              category
#  446  shdpay11              category
#  447  incdiffs              category
#  448  incdiff               category
#  449  unempsol              category
#  450  mkt1                  category
#  451  respineq              category
#  452  goveff2               category
#  453  goveff1               category
#  454  hilowtax              category
#  455  taxhisc2              category
#  456  buyhlth               category
#  457  buyeducn              category
#  458  anger1                category
#  459  wrlddiff              category
#  460  helppoor              category
#  461  migrpoor              category
#  462  conflic1              category
#  463  conflic2              category
#  464  conflic4              category
#  465  conflic6              category
#  466  conflic8              category
#  467  subclass              category
#  468  socscale              category
#  469  socscl10              category
#  470  socsclfut             category
#  471  dpayresp              category
#  472  dpayeduc              category
#  473  dpaychld              category
#  474  dpaywell              category
#  475  socdiag1              category
#  476  socdiag2              category
#  477  fairdist              category
#  478  contpoor              category
#  479  contrich              category
#  480  makeem                category
#  481  makeemft              category
#  482  skipmeal              category
#  483  peoptrst              category
#  484  femprel               category
#  485  memprel               category
#  486  falsconf              category
#  487  cheatpor              category
#  488  ben3000               category
#  489  ben3000d              category
#  490  coha3000              category
#  491  falcatch              category
#  492  povconc               category
#  493  povgov                category
#  494  hlthgap               category
#  495  childmh1              category
#  496  childmh2              category
#  497  childmh3              category
#  498  childmh4              category
#  499  childmh5              category
#  500  statsec1a             category
#  501  quldev3b              category
#  502  quldev4b              category
#  503  quldev9b              category
#  504  quldev10b             category
#  505  lrnskll               category
#  506  robown2               category
#  507  eurel                 category
#  508  coneurel              category
#  509  labeurel              category
#  510  eutrdmv               category
#  511  TPrWrong2             category
#  512  trafeel1              category
#  513  trafeel2              category
#  514  trafeel3              category
#  515  trafeel4              category
#  516  trafeel5              category
#  517  trafeel6              category
#  518  trafeel7              category
#  519  trafeel8              category
#  520  trapolic              category
#  521  traprims              category
#  522  parchill              category
#  523  parlaun               category
#  524  parhwk                category
#  525  parmeal               category
#  526  parbike               category
#  527  parbday               category
#  528  sxbstrm2              category
#  529  sxwkatm               category
#  530  sxwktchm              category
#  531  sxbstrw2              category
#  532  sxwkatw               category
#  533  sxwktchw              category
#  534  stopsmok              category
#  535  withdraw              category
#  536  vappleas              category
#  537  cutcig                category
#  538  vapcost               category
#  539  helpquit              category
#  540  welfhelp              category
#  541  morewelf              category
#  542  unempjob              category
#  543  sochelp               category
#  544  dolefidl              category
#  545  welffeet              category
#  546  damlives              category
#  547  proudwlf              category
#  548  redistrb              category
#  549  bigbusnn              category
#  550  wealth                category
#  551  richlaw               category
#  552  indust4               category
#  553  tradvals              category
#  554  stifsent              category
#  555  deathapp              category
#  556  obey                  category
#  557  wronglaw              category
#  558  censor                category
#  559  leftrigh              category
#  560  libauth               category
#  561  welfare2              category
#  562  libauth2              category
#  563  leftrig2              category
#  564  welfgrp               category
#  565  NatBrit               category
#  566  NatEng                category
#  567  NatEuro               category
#  568  eq_inc_deciles        category
#  569  eq_inc_quintiles      category
#  570  eq_bhcinc2_deciles    category
#  571  eq_bhcinc2_quintiles  category
# dtypes: category(571), float64(1)
# memory usage: 2.2 MB

# %% [markdown]
# **xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx**

# %% [markdown]
# ## Data Preprocessing

# %%
dataset.isnull().sum() # Total NULL Values Before Preprocessing
# Out:
# Sserial                   0
# spoint                    0
# StratID                   0
# WtFactor                  0
# OldWt                     0
#                        ...
# NatEuro                   0
# eq_inc_deciles          932
# eq_inc_quintiles        932
# eq_bhcinc2_deciles      865
# eq_bhcinc2_quintiles    865
# Length: 572, dtype: int64

# %%
dataset = dataset.dropna(axis = 1, inplace = False) # Removing Columns with NULL Values

# %%
dataset.isnull().sum() # Total NULL Values After Preprocessing
# Out:
# Sserial     0
# spoint      0
# StratID     0
# WtFactor    0
# OldWt       0
#            ..
# HHIncQ      0
# SelfComp    0
# NatBrit     0
# NatEng      0
# NatEuro     0
# Length: 167, dtype: int64

# %%
# Changing Data Type of every Column in the Dataset

for col in dataset.columns:
    dataset[col] = dataset[col].astype(object)

# %% [markdown]
# **xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx**

# %% [markdown]
# ## Synthetic Data Generation

# %% [markdown]
# ### Gaussian Copula Model

# %%
syn_model = GaussianCopula() # Initializing the Model
syn_model.fit(dataset) # Applying the Model on the Data

# %% [markdown]
# #### Saving The Synthetic Data Generator Model

# %%
syn_model.save('Saved Model/Gaussian.pkl')

# %% [markdown]
# #### Loading The Saved Synthetic Data Generator Model

# %%
gaussian = GaussianCopula.load('Saved Model/Gaussian.pkl')

# %%
syn_data = gaussian.sample(num_rows = 100) # Generating Synthetic Instances
syn_data # Printing the Data
# Out:
#      Sserial spoint StratID  WtFactor     OldWt     ABCVer   Country  \
# 0   310505.0  342.0   117.0  1.379188  0.559625  Version A   England
# 1   311327.0  404.0   156.0  0.591229  1.678875  Version A   England
# 2   312459.0  190.0   166.0  1.153092   1.11925  Version B   England
# 3   312545.0  127.0   159.0  0.384759  1.678875  Version C  Scotland
# 4   313171.0  412.0   218.0  0.529731   1.11925  Version B   England
# ..       ...    ...     ...       ...       ...        ...       ...
# 95  311140.0  263.0   215.0  1.110789   1.11925  Version B   England
# 96  312056.0  340.0   241.0  0.601899  0.559625  Version B   England
# 97  310770.0  116.0   148.0  2.274837  1.678875  Version A   England
# 98  311730.0  124.0   127.0  0.940085  0.559625  Version C   England
# 99  312775.0  153.0   142.0  0.592553   1.11925  Version A   England
#
#            GOR_ID HousehldE    RSex  ...                          HEdQual3  \
# 0           Wales       3.0  Female  ...                            Degree
# 1           Wales       1.0  Female  ...                            Degree
# 2          London       2.0  Female  ...              O level or equiv/CSE
# 3      South West       4.0    Male  ...                  No qualification
# 4          London       4.0  Female  ...  Higher educ below degree/A level
# ..            ...       ...     ...  ...                               ...
# 95     North West       3.0    Male  ...                            Degree
# 96  East Midlands       2.0    Male  ...  Higher educ below degree/A level
# 97     South East       3.0  Female  ...                  No qualification
# 98  East Midlands        5+  Female  ...                            Degree
# 99          Wales       2.0  Female  ...              O level or equiv/CSE
#
#       EUParVot   AnyBN3                                           MainInc5  \
# 0           No       No             State retirement or widow's pension(s)
# 1           No      Yes  Earnings from employment (own or spouse / part...
# 2           No      Yes                                 Private pension(s)
# 3           No      Yes             State retirement or widow's pension(s)
# 4   Yes, voted      Yes  Earnings from employment (own or spouse / part...
# ..         ...      ...                                                ...
# 95  Yes, voted  Refusal  Earnings from employment (own or spouse / part...
# 96          No      Yes  Incapacity benefit / Employment and Support Al...
# 97  Yes, voted  Refusal  Jobseeker's Allowance (CAN INCLUDE PENSIONER P...
# 98          No      Yes  Earnings from employment (own or spouse / part...
# 99  Yes, voted       No  Earnings from employment (own or spouse / part...
#
#                  HHIncD                 HHIncQ            SelfComp  \
# 0   £4,911 - 6,610 p.m.  Less than £1,410 p.m.                 yes
# 1   £2,561 - 3,160 p.m.    £2,561 - 4,350 p.m.                 yes
# 2   Less than £920 p.m.    £2,561 - 4,350 p.m.  no self completion
# 3   £6,611 or more p.m.    Refused information  no self completion
# 4   £1,591 - 2,030 p.m.  Less than £1,410 p.m.                 yes
# ..                  ...                    ...                 ...
# 95    £921 - 1,240 p.m.    £1,411 - 2,560 p.m.                 yes
# 96           Don`t know    Refused information                 yes
# 97  £1,241 - 1,590 p.m.    £1,411 - 2,560 p.m.                 yes
# 98  £3,891 - 4,910 p.m.    £2,561 - 4,350 p.m.                 yes
# 99  £4,911 - 6,610 p.m.             Don`t know                 yes
#
#           NatBrit         NatEng        NatEuro
# 0       Mentioned  Not mentioned  Not mentioned
# 1       Mentioned      Mentioned  Not mentioned
# 2       Mentioned  Not mentioned  Not mentioned
# 3   Not mentioned      Mentioned  Not mentioned
# 4       Mentioned  Not mentioned  Not mentioned
# ..            ...            ...            ...
# 95      Mentioned  Not mentioned      Mentioned
# 96        Refusal  Not mentioned      Mentioned
# 97      Mentioned      Mentioned      Mentioned
# 98      Mentioned        Refusal  Not mentioned
# 99      Mentioned  Not mentioned      Mentioned
#
# [100 rows x 167 columns]

# %% [markdown]
# #### Evaluating Synthetic Instances

# %% [markdown]
# Statistical Metrics

# %%
general_evaluation = evaluate(syn_data, dataset) # Evaluating on All Metrics
CS_test = evaluate(syn_data, dataset, metrics = ['CSTest']) # Chi-Squared Test
KS_test = evaluate(syn_data, dataset, metrics = ['KSTest']) # Inverted Kolmogorov-Smirnov Test

# %%
evaluation = [general_evaluation, CS_test, KS_test] # Creating a List of the Results
evaluation = pd.DataFrame(evaluation) # Creating a Data Frame of the Results
evaluation.columns = ['Results'] # Gicing Column Name
evaluation.rename({0:'General Evaluation', 1:'Chi-Squared Test', 2:'Inverted Kolmogorov-Smirnov Test'}) # Renaming Row Name
# Out:
#                                    Results
# General Evaluation                0.515714
# Chi-Squared Test                  0.865854
# Inverted Kolmogorov-Smirnov Test       NaN

# %%
p_CS_test = 1-CS_test # Calculating 'p-value' for Chi-Squared Test
p_KS_test = 1-KS_test # Calculating 'p-value' for Inverted Kolmogorov-Smirnov Test

# %%
p_value = [p_CS_test, p_KS_test] # Creating a List of the Results
p_value = pd.DataFrame(p_value) # Creating a Data Frame of the Results
p_value.columns = ['P Values'] # Gicing Column Name
p_value.rename({0:'Chi-Squared P Value', 1:'Inverted Kolmogorov-Smirnov P Value'}) # Renaming Row Name
# Out:
#                                      P Values
# Chi-Squared P Value                  0.134146
# Inverted Kolmogorov-Smirnov P Value       NaN

# %% [markdown]
# **xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx**
